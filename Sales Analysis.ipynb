# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('1673872777_ausapparalsales4thqrt2020.xlsx')

# %%
df.head()
# Out:
#         Date        Time State     Group  Unit  Sales
# 0 2020-10-01     Morning    WA      Kids     8  20000
# 1 2020-10-01     Morning    WA       Men     8  20000
# 2 2020-10-01     Morning    WA     Women     4  10000
# 3 2020-10-01     Morning    WA   Seniors    15  37500
# 4 2020-10-01   Afternoon    WA      Kids     3   7500

# %%
df.tail()
# Out:
#            Date        Time State     Group  Unit  Sales
# 7555 2020-12-30   Afternoon   TAS   Seniors    14  35000
# 7556 2020-12-30     Evening   TAS      Kids    15  37500
# 7557 2020-12-30     Evening   TAS       Men    15  37500
# 7558 2020-12-30     Evening   TAS     Women    11  27500
# 7559 2020-12-30     Evening   TAS   Seniors    13  32500

# %%
df.describe()
# Out:
#               Unit          Sales
# count  7560.000000    7560.000000
# mean     18.005423   45013.558201
# std      12.901403   32253.506944
# min       2.000000    5000.000000
# 25%       8.000000   20000.000000
# 50%      14.000000   35000.000000
# 75%      26.000000   65000.000000
# max      65.000000  162500.000000

# %%
df.shape
# Out:
# (7560, 6)

# %%
df.isnull().sum()
# Out:
# Date     0
# Time     0
# State    0
# Group    0
# Unit     0
# Sales    0
# dtype: int64

# %%
df.dtypes
# Out:
# Date     datetime64[ns]
# Time             object
# State            object
# Group            object
# Unit              int64
# Sales             int64
# dtype: object

# %%
sns.countplot(df['State'])
# Out:
# C:\Users\Vinosh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
sns.countplot(df['Group'])
# Out:
# C:\Users\Vinosh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Group', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Unit'])
# Out:
# C:\Users\Vinosh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Unit', ylabel='count'>

# %%
sns.kdeplot(x=df['Sales'],hue=df['Group'])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.kdeplot(x=df['Sales'],hue=df['State'])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.barplot(y=df['Sales'],x=df['State'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
sns.barplot(y=df['Unit'],x=df['State'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Unit'>

# %%
sns.scatterplot(x=df['State'],y=df['Sales'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
sns.barplot(x=df['Group'],y=df['Sales'])
# Out:
# <AxesSubplot:xlabel='Group', ylabel='Sales'>

# %%
sns.barplot(x=df['Group'],y=df['Unit'])
# Out:
# <AxesSubplot:xlabel='Group', ylabel='Unit'>

# %%
sns.barplot(x=df['Time'],y=df['Sales'])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Sales'>

# %%
sns.barplot(y=df['Unit'],x=df['Time'])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Unit'>

# %%
sns.boxplot(x=df['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
sns.boxplot(df['Unit'])
# Out:
# C:\Users\Vinosh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Unit'>

# %%
df_master = df.copy()

# %%
df_master
# Out:
#            Date        Time State     Group  Unit  Sales
# 0    2020-10-01     Morning    WA      Kids     8  20000
# 1    2020-10-01     Morning    WA       Men     8  20000
# 2    2020-10-01     Morning    WA     Women     4  10000
# 3    2020-10-01     Morning    WA   Seniors    15  37500
# 4    2020-10-01   Afternoon    WA      Kids     3   7500
# ...         ...         ...   ...       ...   ...    ...
# 7555 2020-12-30   Afternoon   TAS   Seniors    14  35000
# 7556 2020-12-30     Evening   TAS      Kids    15  37500
# 7557 2020-12-30     Evening   TAS       Men    15  37500
# 7558 2020-12-30     Evening   TAS     Women    11  27500
# 7559 2020-12-30     Evening   TAS   Seniors    13  32500
#
# [7560 rows x 6 columns]

# %%
df_master['Time'].value_counts()
# Out:
#  Morning      2520
#  Afternoon    2520
#  Evening      2520
# Name: Time, dtype: int64

# %%
df_master['Time'] = df_master['Time'].replace(' Morning','0')
df_master['Time'] = df_master['Time'].replace(' Afternoon','1')
df_master['Time'] = df_master['Time'].replace(' Evening','2')

# %%
df_master.dtypes
# Out:
# Date     datetime64[ns]
# Time             object
# State            object
# Group            object
# Unit              int64
# Sales             int64
# dtype: object

# %%
df_master['Time'] = df_master['Time'].astype(int)

# %%
df_master['Time'].value_counts()
# Out:
# 0    2520
# 1    2520
# 2    2520
# Name: Time, dtype: int64

# %%
df_master['State'].value_counts()
# Out:
#  WA     1080
#  NT     1080
#  SA     1080
#  VIC    1080
#  QLD    1080
#  NSW    1080
#  TAS    1080
# Name: State, dtype: int64

# %%
df_master['State'] = df_master['State'].replace(' WA','0')
df_master['State'] = df_master['State'].replace(' NT','1')
df_master['State'] = df_master['State'].replace(' SA','2')
df_master['State'] = df_master['State'].replace(' VIC','3')
df_master['State'] = df_master['State'].replace(' QLD','4')
df_master['State'] = df_master['State'].replace(' NSW','5')
df_master['State'] = df_master['State'].replace(' TAS','6')

# %%
df_master.dtypes
# Out:
# Date     datetime64[ns]
# Time              int32
# State            object
# Group            object
# Unit              int64
# Sales             int64
# dtype: object

# %%
df_master['State'] = df_master['State'].astype(int)

# %%
df_master['State'].value_counts()
# Out:
# 0    1080
# 1    1080
# 2    1080
# 3    1080
# 4    1080
# 5    1080
# 6    1080
# Name: State, dtype: int64

# %%
df_master.dtypes
# Out:
# Date     datetime64[ns]
# Time              int32
# State             int32
# Group            object
# Unit              int64
# Sales             int64
# dtype: object

# %%
df_master['Group'].value_counts()
# Out:
#  Kids       1890
#  Men        1890
#  Women      1890
#  Seniors    1890
# Name: Group, dtype: int64

# %%
df_master['Group'] = df_master['Group'].replace(' Kids','0')
df_master['Group'] = df_master['Group'].replace(' Men','1')
df_master['Group'] = df_master['Group'].replace(' Women','2')
df_master['Group'] = df_master['Group'].replace(' Seniors','3')

# %%
df_master.dtypes
# Out:
# Date     datetime64[ns]
# Time              int32
# State             int32
# Group            object
# Unit              int64
# Sales             int64
# dtype: object

# %%
df_master['Group'] = df_master['Group'].astype(int)

# %%
df_master.dtypes
# Out:
# Date     datetime64[ns]
# Time              int32
# State             int32
# Group             int32
# Unit              int64
# Sales             int64
# dtype: object

# %%
df_master['Group'].value_counts()
# Out:
# 0    1890
# 1    1890
# 2    1890
# 3    1890
# Name: Group, dtype: int64

# %%
df_master.groupby(['Group','Time']).size().unstack().plot(kind='barh',legend=True)
plt.title('Group Affecting')
plt.show()

# %%
df_master.shape
# Out:
# (7560, 6)

# %%
df_master.columns
# Out:
# Index(['Date', 'Time', 'State', 'Group', 'Unit', 'Sales'], dtype='object')

# %%
X = df_master[['Time','State','Group','Unit']]

# %%
y = df_master['Sales']

# %%
X = df_master[['Time','State','Group','Unit']].values

# %%
y = df_master['Sales'].values

# %%
y
# Out:
# array([20000, 20000, 10000, ..., 37500, 27500, 32500], dtype=int64)

# %%
X
# Out:
# array([[ 0,  0,  0,  8],
#        [ 0,  0,  1,  8],
#        [ 0,  0,  2,  4],
#        ...,
#        [ 2,  6,  1, 15],
#        [ 2,  6,  2, 11],
#        [ 2,  6,  3, 13]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train.shape
# Out:
# (6048, 4)

# %%
y_train.shape
# Out:
# (6048,)

# %%
X_test.shape
# Out:
# (1512, 4)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(X_test)

# %%
y_predict
# Out:
# array([30000., 25000., 37500., ..., 62500., 50000., 15000.])

# %%
y_test
# Out:
# array([30000, 25000, 37500, ..., 62500, 50000, 15000], dtype=int64)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 9.482848873403382e-22

# %%
from sklearn.feature_selection import f_regression

# %%
f_regression(X_train,y_train)
# Out:
# (array([8.44909102e-01, 1.71685342e+02, 2.04179214e-01, 1.60169196e+18]),
#  array([3.58033198e-01, 1.06330485e-38, 6.51384652e-01, 0.00000000e+00]))

# %%
from sklearn import metrics

# %%
metrics.r2_score(y_test,y_predict)
# Out:
# 1.0

# %% [markdown]
# # Summary

# %% [markdown]
# 1. The state VIC generates the highest Revenue
# 2. The state WA, NT and TAS generates the less revenue
# 3. VIC sold the highest number of Units
# 4. WA, NT and TAS sold the less number of Units
# 5. The newly opened branches are doing good and by the prediction its the right decisions to expand the company.
